# %%
import import_ipynb
from quadrotor_sims_params import *
# Out:
# importing Jupyter notebook from quadrotor_sims_params.ipynb
# importing Jupyter notebook from quadrotor_dynamics.ipynb

# %%
if __name__ == '__main__':
    fly_quadrotor()
